# %%
from loanpy.qfysc import Etym

# %%
etym_obj = Etym("cldf/forms.csv", source_language="WOT", target_language="EAH")

# %%
etym_obj.get_scdictbase(write_to="etc/scWOT2EAH.txt")  # 1.7MB!
# Out:
# 100%|█████████████████████████████████████| 6489/6489 [00:02<00:00, 2555.96it/s]
# {'˩': ['r',
#   'ɛ',
#   'ɒ',
#   'i',
#   'a',
#   'eː',
#   'ɯ',
#   'o',
#   'u',
#   'øː',
#   'uː',
#   'e',
#   'y',
#   'aː',
#   'ø',
#   'iː',
#   'yː',
#   'w',
#   'mː',
#   'ɲ',
#   'p',
#   'b',
#   'm',
#   'j',
#   'ɟ',
#   'k',
#   'h',
#   'ŋ',
#   'ɣ',
#   'ɡ',
#   'β',
#   'd͡ʒʲ',
#   'v',
#   'z',
#   'l',
#   'n',
#   't͡ʃ',
#   'lː',
#   'tː',
#   's',
#   't',
#   'd',
#   'ʃ'],
#  '˨': ['r',
#   'ɛ',
#   'ɒ',
#   'i',
#   'a',
#   'eː',
#   'ɯ',
#   'o',
#   'u',
#   'øː',
#   'uː',
#   'e',
#   'y',
#   'aː',
#   'ø',
#   'iː',
#   'yː',
#   'w',
#   'mː',
#   'ɲ',
#   'p',
#   'b',
#   'm',
#   'j',
#   'ɟ',
#   'k',
#   'h',
#   'ŋ',
#   'ɣ',
#   'ɡ',
#   'β',
#   'd͡ʒʲ',
#   'v',
#   'z',
#   'l',
#   'n',
#   't͡ʃ',
#   'lː',
#   'tː',
#   's',
#   't',
#   'd',
#   'ʃ'],
#  '˧': ['r',
#   'ɛ',
#   'ɒ',
#   'i',
#   'a',
#   'eː',
#   'ɯ',
#   'o',
#   'u',
#   'øː',
# ...

# %%
from loanpy.qfysc import Qfy
qfy_obj = Qfy("cldf/forms.csv", "WOT", "EAH", scdictbase="etc/scWOT2EAH.txt", mode="adapt")
qfy_obj.get_sound_corresp("etc/scWOT2EAH.txt")
# Out:
# [{'C': ['ɡ',
#    'n',
#    'm',
#    't',
#    's',
#    'j',
#    'ɣ',
#    'p',
#    'w',
#    'h',
#    'l',
#    'r',
#    'ŋ',
#    'lː',
#    'ɲ',
#    'mː',
#    'β',
#    'v',
#    'z',
#    'ʃ',
#    'k',
#    'b',
#    'ɟ',
#    'd',
#    't͡ʃ',
#    'tː',
#    'd͡ʒʲ'],
#   'V': ['a',
#    'i',
#    'ɛ',
#    'u',
#    'ɯ',
#    'o',
#    'e',
#    'ɒ',
#    'eː',
#    'ø',
#    'øː',
#    'aː',
#    'iː',
#    'uː',
#    'y',
#    'yː'],
#   'a': ['a',
#    'aː',
#    'o',
#    'ɒ',
#    '',
#    'i',
#    'u',
#    'e',
#    'ɛ',
#    'eː',
#    'ø',
#    'øː',
#    'iː',
#    'ɯ',
#    'y',
#    'yː',
#    'uː',
#    'j',
#    'w',
#    'h',
#    'l',
#    'r',
#    'lː',
#    'ɲ',
#    'm',
#    'n',
#    'mː',
#    'ŋ',
#    'β',
#    'v',
#    'z',
#    's',
#    'ʃ',
#    'ɣ',
#    'b',
#    'ɟ',
#    'd',
#    'p',
#    't',
#    'ɡ',
#    'k',
#    't͡ʃ',
#    'tː',
#    'd͡ʒʲ'],
#   'aː': ['a',
#    'aː',
#    'eː',
#    'øː',
#    'e',
#    'iː',
#    'ɛ',
# ...

# %%
from loanpy.qfysc import Qfy
qfy_obj = Qfy("cldf/forms.csv", "H", "EAH", mode="reconstruct")
qfy_obj.get_sound_corresp("etc/scH2EAH.txt")
# Out:
# [{'#-': ['-', 'v'],
#   '#aː': ['a', 'aː', 'o'],
#   '#b': ['b'],
#   '#c': ['t'],
#   '#d': ['d', 'd͡ʒʲ', 't'],
#   '#e': ['e'],
#   '#eː': ['ɛ'],
#   '#h': ['h', 'ks', '-'],
#   '#i': ['i', 'y', 'ɛ'],
#   '#iː': ['i'],
#   '#k': ['k'],
#   '#l': ['v'],
#   '#m': ['m'],
#   '#o': ['u', 'o', 'a'],
#   '#oː': ['a'],
#   '#s': ['s'],
#   '#t': ['t'],
#   '#t͡s': ['s', 't͡ʃ'],
#   '#t͡ʃ': ['t͡ʃ'],
#   '#u': ['u'],
#   '#uː': ['u'],
#   '#v': ['v'],
#   '#y': ['i', 'ɛ', 'y', 'ø'],
#   '#z': ['s'],
#   '#ø': ['y', 'ɛ', 'ø', 'i'],
#   '#øː': ['ɛ'],
#   '#ɒ': ['a', 'o'],
#   '#ɛ': ['ɛ', 'i'],
#   '#ɟ': ['d͡ʒʲ', 'ɟ'],
#   '#ɡ': ['ɡ', 'k'],
#   '#ɲ': ['n'],
#   '#ʃ': ['ʃ', 't͡ʃ', 's'],
#   '-#': ['-',
#    'ɣ',
#    'i',
#    'iɣ',
#    'y',
#    'ɛ',
#    'an',
#    'u',
#    'ur',
#    'ɣu',
#    'at',
#    'in',
#    'ɛk',
#    'v',
#    'øk',
#    'ɛn',
#    'yr',
#    'ɣaɣ',
#    'ɣy',
#    'j',
#    'ɒ',
#    'uk',
#    'at͡ʃi',
#    'ruɣ',
#    'l',
#    'ut',
#    'ol',
#    'yt͡ʃi',
# ...

# %%
from loanpy.adrc import Adrc

# %%
ad_obj = Adrc(scdictlist="etc/scWOT2EAH.txt", forms_csv="cldf/forms.csv", source_language="WOT",
                target_language="EAH", mode="adapt")

# %%
from epitran import Epitran
epi = Epitran("hun-Latn")

# %%
epi.transliterate("madár")  # hɪrɪ
# Out:
# 'mɒdaːr'

# %%
ad_obj.adapt("ɸuɣl̥s", 100, max_repaired_phonotactics=1, sort_by_nse=True, show_workflow=True)
# Out:
# 'βuɣlɯs, vuɣlɯs, βuɣlis, vuɣlis, βuɣlɛs, βuɣlas, vuɣlɛs, vuɣlas, βuɣlus, βuɣlos, vuɣlus, vuɣlos, βuɣles, vuɣles, βuɣlɯz, vuɣlɯz, βuɣliz, vuɣliz, βuɣlɛz, βuɣlaz, vuɣlɛz, vuɣlaz, βuɣluz, βuɣloz, vuɣluz, vuɣloz, βuɣlez, vuɣlez, βoɣlɯs, voɣlɯs, βoɣlis, voɣlis, βoɣlɛs, βoɣlas, voɣlɛs, voɣlas, βɣlɯs, vɣlɯs, βoɣlus, βoɣlos, voɣlus, voɣlos, βɣlis, vɣlis, βoɣles, voɣles, βɣlɛs, βɣlas, vɣlɛs, vɣlas, βɣlus, βɣlos, vɣlus, vɣlos, βɣles, vɣles, βulɯs, vulɯs, βulis, vulis, βulɛs, βulas, vulɛs, vulas, βulus, βulos, vulus, vulos, βules, vules, βoɣlɯz, voɣlɯz, βoɣliz, voɣliz, βoɣlɛz, βoɣlaz, voɣlɛz, voɣlaz, βɣlɯz, vɣlɯz, βoɣluz, βoɣloz, voɣluz, voɣloz, βɣliz, vɣliz, βoɣlez, voɣlez, βɣlɛz, βɣlaz, vɣlɛz, vɣlaz, βɣluz, βɣloz, vɣluz, vɣloz, βɣlez, vɣlez, βulɯz, vulɯz'

# %%
ad_obj.workflow
# Out:
# OrderedDict([('tokenised', "['ɸ', 'u', 'ɣ', 'l̥', 's']"),
#              ('donor_phonotactics', 'CVCCC'),
#              ('predicted_phonotactics', "['CVCCVC']"),
#              ('adapted_phonotactics', "[['ɸ', 'u', 'ɣ', 'l̥', 'V', 's']]"),
#              ('before_combinatorics',
#               "[[['β', 'v'], ['u', 'o', ''], ['ɣ', ''], ['l'], ['a', 'i', 'ɛ', 'u', 'ɯ', 'o', 'e'], ['s', 'z']]]")])

# %%
rc_obj = Adrc(scdictlist="etc/scH2EAH.txt", forms_csv="cldf/forms.csv", source_language="H",
                target_language="EAH", mode="reconstruct")

# %%
rc_obj.reconstruct("aːɟuː", howmany=1000, vowelharmony_filter=True, phonotactics_filter=True, clusterised=True)
# Out:
# '^alda$|^aldaɣ$|^aldav$|^aldaɣaɣ$|^aldaj$|^aldal$|^aldarɛɣ$|^aldan$|^aldaɡ$|^aldariɣ$|^aldanɛɣ$|^ada$|^adaɣ$|^adav$|^adaɣaɣ$|^adaj$|^adal$|^adarɛɣ$|^adan$|^adaɡɛliɣ$|^adaɡ$|^adariɣ$|^adanɛɣ$|^aːlda$|^aːldaɣ$|^aːldav$|^aːldaɣaɣ$|^aːldaj$|^aːldal$|^aːldarɛɣ$|^aːldan$|^aːldaɡ$|^aːldariɣ$|^aːldanɛɣ$|^aːda$|^aːdaɣ$|^aːdav$|^aːdaɣaɣ$|^aːdaj$|^aːdal$|^aːdarɛɣ$|^aːdan$|^aːdaɡɛliɣ$|^aːdaɡ$|^aːdariɣ$|^aːdanɛɣ$|^oldu$|^olduɣ$|^olduv$|^olduj$|^olduruɣ$|^oldul$|^oldun$|^olduɡ$|^oldo$|^oldoɣ$|^oldov$|^oldoj$|^oldoruɣ$|^oldol$|^oldon$|^oldoɡ$|^odu$|^oduɣ$|^oduv$|^oduj$|^oduruɣ$|^odul$|^odun$|^oduɡ$|^odo$|^odoɣ$|^odov$|^odoj$|^odoruɣ$|^odol$|^odon$|^odoɡ$|^valda$|^valdaɣ$|^valdav$|^valdaɣaɣ$|^valdaj$|^valdal$|^valdarɛɣ$|^valdan$|^valdaɡ$|^valdariɣ$|^valdanɛɣ$|^vada$|^vadaɣ$|^vadaiɣ$|^vadaan$|^vadaat$|^vadain$|^vadaɛk$|^vadav$|^vadaøk$|^vadaɛn$|^vadayr$|^vadaɣaɣ$|^vadaɣy$|^vadaj$|^vadal$|^vadayz$|^vadail$|^vadaɛɡ$|^vadakɛ$|^vadarɛɣ$|^vadan$|^vadaiz$|^vadayɣ$|^vadaɡɛliɣ$|^vadair$|^vadaɡ$|^vadariɣ$|^va
# ...

# %%
import os
from pathlib import Path
print(Path(os.getcwd(), "sc"))
# Out:
# /home/viktor/Documents/GitHub/ronataswestoldturkic/sc

# %%
from loanpy.sanity import eval_all, cache
from pathlib import Path
import os

eval_all = cache(eval_all)

eval_all(forms_csv="cldf/forms.csv",
         source_language="WOT",
         target_language="EAH",
         mode="adapt",
         write_to="etc/adapt.csv",
         path2cache="etc/cache2.csv",
         writesc=False)  # Path(os.getcwd(), "etc/sc"))
# Out:
# ---------------------------------------------------------------------------
# ArgumentsAlreadyTested                    Traceback (most recent call last)
# Cell In[2], line 7
#       3 import os
#       5 eval_all = cache(eval_all)
# ----> 7 eval_all(forms_csv="cldf/forms.csv",
#       8          source_language="WOT",
#       9          target_language="EAH",
#      10          mode="adapt",
#      11          write_to="etc/adapt.csv",
#      12          path2cache="etc/cache2.csv",
#      13          writesc=False)  # Path(os.getcwd(), "etc/sc"))
#
# File ~/.local/lib/python3.8/site-packages/loanpy/sanity.py:88, in cache.<locals>.wrapped(*args, **kwargs)
#      84 @wraps(method)
#      85 def wrapped(*args, **kwargs):
#      86     path2cache, init_args = {**kwargs}["path2cache"], {**kwargs, **dict(
#      87         zip(["forms_csv", "tgt_lg", "src_lg"], [*args]))}
# ---> 88     check_cache(path2cache, init_args)
#      89     result = method(*args, **kwargs)
# ...

# %%
from loanpy.sanity import eval_all, cache
from pathlib import Path
import os

eval_all = cache(eval_all)

eval_all(forms_csv="cldf/forms.csv",
         source_language="H",
         target_language="EAH",
         mode="reconstruct",
         write_to="etc/reconstruct.csv",
         path2cache="etc/cache.csv",
         writesc=False)  # Path(os.getcwd(), "etc/sc"))
# Out:
# 489it [00:53,  9.21it/s]

# %%
from loanpy.sanity import eval_all, cache
from loanpy.sanity import ArgumentsAlreadyTested

eval_all = cache(eval_all)

for cl in [True, False]:
    for ph_f in [True, False]:
        for vh in [True, False]:
            try:
                eval_all(forms_csv="cldf/forms.csv",
                         source_language="EAH",
                         target_language="H",
                         mode="reconstruct",
                         write_to="etc/opt_params.csv",
                         path2cache="etc/cache.csv",
                         clusters=cl,
                         vowelharmony=vh,
                         phonotactics_filter=ph_f)
            except ArgumentsAlreadyTested:
                print("arguments already tested")
# Out:
# 489it [01:00,  8.11it/s]
# 489it [00:59,  8.23it/s]
# 489it [00:59,  8.26it/s]
# 489it [00:49,  9.92it/s]
# 489it [01:00,  8.09it/s]
# 489it [00:56,  8.59it/s]
# 489it [00:58,  8.40it/s]
# 489it [00:49,  9.87it/s]

# %%
from loanpy.sanity import eval_all, cache
from loanpy.sanity import ArgumentsAlreadyTested

#eval_all = cache(eval_all)

try:
    eval_all(guesslist=[10, 50, 100, 500, 1000, 2000],
             forms_csv="cldf/forms.csv",
             source_language="EAH",
             target_language="H",
             mode="reconstruct",
             write_to="etc/opt_params.csv",
             path2cache="etc/cache.csv",
             clusters=True,
             vowelharmony=False,
             phonotactics_filter=True)
except ArgumentsAlreadyTested:
    print("arguments already tested")
# Out:
# 489it [01:03,  7.69it/s]

# %%
from loanpy.sanity import eval_all, cache

eval_all = cache(eval_all)

for cl in [True, False]:
    for ph_f in [True, False]:
        for vh in [True, False]:
            eval_all(forms_csv="cldf/forms.csv",
                     source_language="WOT",
                     target_language="EAH",
                     mode="adapt",
                     write_to="etc/opt_params.csv",
                     path2cache="etc/cache.csv",
                     clusters=cl,
                     vowelharmony=vh,
                     phonotactics_filter=ph_f)
